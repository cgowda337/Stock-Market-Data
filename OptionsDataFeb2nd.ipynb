# %%
# Import packages
import yfinance as yf
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as ts
from matplotlib import pyplot as plt
import statistics
import math
#test

# %%
df = pd.read_excel(r'C:\Users\Chetan\Desktop\STOCK STUFF\Data\SPXOptions2223.xlsx')
df.head()
# Out:
#        Time            Option  QTY  Price Exchange       Market  Delta  \
# 0  20:47:39   3 FEB 23 4050 P   20   0.90     CBOE      .85x.95  -0.03
# 1  20:47:27   3 FEB 23 4000 P    9   0.22     CBOE      .20x.25  -0.01
# 2  20:47:27   3 FEB 23 4175 C    9  13.55     CBOE  13.30x13.70   0.58
# 3  20:47:27  10 FEB 23 4000 P    9   5.83     CBOE    5.60x6.10  -0.09
# 4  20:47:27  10 FEB 23 4175 C    9  32.14     CBOE  31.90x32.70   0.55
#
#        IV  Underlying Unnamed: 9
# 0  0.3737     4179.76        NaN
# 1  0.4036     4179.76        NaN
# 2  0.1412     4179.76        NaN
# 3  0.2305     4179.76        NaN
# 4  0.1144     4179.76        NaN

# %%
plt.scatter(df['Delta'],df['QTY'])

# %%
cm = plt.cm.get_cmap('YlGnBu')
n, bins, patches = plt.hist(df['Delta'])
plt.title("SPX Deltas Distribution Feb 2nd")
col = (n-n.min())/(n.max()-n.min())
for c, p in zip(col, patches):
    plt.setp(p, 'facecolor', cm(c))
plt.show()

# %%
n, bins, patches = plt.hist(df['Underlying'])
for i, p in enumerate(patches):
    plt.setp(p, 'facecolor', cm(i/25)) # notice the i/25

plt.title("Trades at Price Feb2nd")
# Out:
# Text(0.5, 1.0, 'Trades at Price Feb2nd')

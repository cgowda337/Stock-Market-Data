# %%
# Import packages
import yfinance as yf
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as ts
from matplotlib import pyplot as plt
import statistics
import math

# %%
#target volatility
target_vol = 0.125

# %%
#download data for close
fut_list = ['SPY']
data2= yf.download(fut_list, start="2018-01-01", end="2023-03-14")['Adj Close'] 
df2 = pd.DataFrame(data=data2)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#volatility calculation
vol = pd.DataFrame(data=(((df2.pct_change(1).rolling(20)).std()))*(252**0.5))
vol
# Out:
#             Adj Close
# Date
# 2018-01-02        NaN
# 2018-01-03        NaN
# 2018-01-04        NaN
# 2018-01-05        NaN
# 2018-01-08        NaN
# ...               ...
# 2023-03-07   0.155246
# 2023-03-08   0.146153
# 2023-03-09   0.154474
# 2023-03-10   0.158898
# 2023-03-13   0.157901
#
# [1307 rows x 1 columns]

# %%
bob = target_vol/vol
np.clip(bob, 0, 1).plot()
plt.title('Leverage(12.5% Vol Target)')
plt.xlabel('Date')
plt.ylabel('Leverage')
# Out:
# Text(0, 0.5, 'Leverage')

# %%
x = df2.diff(30)
y = df2.diff(90)
#x.plot()
#y.plot()

# %%
plt.hexbin(df2,vol,cmap = 'viridis')
plt.ylim(0,0.15)
plt.show()

# %%
# Import packages
import yfinance as yf
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as ts
from matplotlib.pyplot import plot, show, draw, figure, cm
from matplotlib import animation
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
# Out:
# C:\Users\Chetan\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fut_list = ['ES=F', '^VIX']
datacorr= yf.download(fut_list, start="2016-01-01", end="2023-01-31")['Close']
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = pd.DataFrame(data=datacorr)
x = df['ES=F'].pct_change(30)
y = df['^VIX'].diff(30)
z = df['^VIX'].pct_change(30)

# %%
ax = plt.axes(projection ="3d")
colors =["blue","green"]
ax.scatter3D(x,y,z, marker = 'o')

# %%
plt.hexbin(x,z)
